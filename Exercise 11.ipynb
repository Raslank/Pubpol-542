# %%
Link="https://docs.google.com/spreadsheets/d/e/2PACX-1vQE9QNuiBB2vz4TStYAyOdmnyqur7uRa8g09cbPrwfPbIALaE7lPaG6PMQ5Qtqq8piNDdlvbg_9lzPl/pub?gid=435191919&single=true&output=csv"

# %%
import pandas as pd
hdi=pd.read_csv(Link)

# %%
hdi
# Out:
#     Unnamed: 0 Table 1. Human Development Index and its components   \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4     HDI rank                                            Country
# ..         ...                                                ...
# 264        NaN                         Column 2: UNDESA (2019b).
# 265        NaN  Column 3: UNESCO Institute for Statistics (201...
# 266        NaN  Column 4: UNESCO Institute for Statistics (201...
# 267        NaN  Column 5: World Bank (2019a), IMF (2019) and U...
# 268        NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# ...

# %%
hdi.iloc[4,1:2].tolist()+hdi.iloc[3,2:3].tolist()
# Out:
# ['Country', 'Human development index (HDI) ']

# %%
Currentheaders=hdi.iloc[4,:2].tolist()+hdi.iloc[3,2:].tolist()

# %%
Currentheaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %%
hdi.head()
# Out:
#   Unnamed: 0 Table 1. Human Development Index and its components   \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4   HDI rank                                            Country
#
#                        Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                             NaN         NaN                       NaN
# 1                             NaN         NaN                      SDG3
# 2                             NaN         NaN                       NaN
# 3  Human development index (HDI)          NaN  Life expectancy at birth
# 4                   (index value)         NaN                   (years)
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# ...

# %%
hdi.drop(index=range(0,7),inplace=True)

# %%
hdi.columns=Currentheaders

# %%
Currentheaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %%
hdi.head()
# Out:
#    HDI rank                 Country Human development index (HDI)   NaN  \
# 7         1                  Norway                          0.954  NaN
# 8         2             Switzerland                          0.946  NaN
# 9         3                 Ireland                          0.942  NaN
# 10        4                 Germany                          0.939  NaN
# 11        4  Hong Kong, China (SAR)                          0.939  NaN
#
#    Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 7                      82.3  NaN                        18.1    b
# 8                      83.6  NaN                        16.2  NaN
# 9                      82.1  NaN                        18.8    b
# 10                     81.2  NaN                        17.1  NaN
# 11                     84.7  NaN                        16.5  NaN
#
#    Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# ...

# %%
hdi.reset_index(drop=True,inplace=True)

# %%
hdi.head()
# Out:
#   HDI rank                 Country Human development index (HDI)   NaN  \
# 0        1                  Norway                          0.954  NaN
# 1        2             Switzerland                          0.946  NaN
# 2        3                 Ireland                          0.942  NaN
# 3        4                 Germany                          0.939  NaN
# 4        4  Hong Kong, China (SAR)                          0.939  NaN
#
#   Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                     82.3  NaN                        18.1    b
# 1                     83.6  NaN                        16.2  NaN
# 2                     82.1  NaN                        18.8    b
# 3                     81.2  NaN                        17.1  NaN
# 4                     84.7  NaN                        16.5  NaN
#
#   Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# ...

# %%
hdi.loc[:,["Country","Human development index (HDI) "]]
# Out:
#                                                Country  \
# 0                                               Norway
# 1                                          Switzerland
# 2                                              Ireland
# 3                                              Germany
# 4                               Hong Kong, China (SAR)
# ..                                                 ...
# 257                         Column 2: UNDESA (2019b).
# 258  Column 3: UNESCO Institute for Statistics (201...
# 259  Column 4: UNESCO Institute for Statistics (201...
# 260  Column 5: World Bank (2019a), IMF (2019) and U...
# 261  Column 6: Calculated based on data in columns ...
#
#     Human development index (HDI)
# 0                            0.954
# 1                            0.946
# 2                            0.942
# 3                            0.939
# 4                            0.939
# ..                             ...
# 257                            NaN
# ...

# %%
hdi=hdi.loc[:,["Country","Human development index (HDI) "]]

# %%
hdi
# Out:
#                                                Country  \
# 0                                               Norway
# 1                                          Switzerland
# 2                                              Ireland
# 3                                              Germany
# 4                               Hong Kong, China (SAR)
# ..                                                 ...
# 257                         Column 2: UNDESA (2019b).
# 258  Column 3: UNESCO Institute for Statistics (201...
# 259  Column 4: UNESCO Institute for Statistics (201...
# 260  Column 5: World Bank (2019a), IMF (2019) and U...
# 261  Column 6: Calculated based on data in columns ...
#
#     Human development index (HDI)
# 0                            0.954
# 1                            0.946
# 2                            0.942
# 3                            0.939
# 4                            0.939
# ..                             ...
# 257                            NaN
# ...

# %%
hdi.tail(65)
# Out:
#                                                Country  \
# 197                                            Somalia
# 198                                             Tuvalu
# 199                                                NaN
# 200                           Human development groups
# 201                        Very high human development
# ..                                                 ...
# 257                         Column 2: UNDESA (2019b).
# 258  Column 3: UNESCO Institute for Statistics (201...
# 259  Column 4: UNESCO Institute for Statistics (201...
# 260  Column 5: World Bank (2019a), IMF (2019) and U...
# 261  Column 6: Calculated based on data in columns ...
#
#     Human development index (HDI)
# 197                             ..
# 198                             ..
# 199                            NaN
# 200                            NaN
# 201                          0.892
# ..                             ...
# 257                            NaN
# ...

# %%
hdi.drop(index=range(199,262),inplace=True)

# %%
hdi.reset_index(drop=True,inplace=True)

# %%
hdi.tail()
# Out:
#         Country Human development index (HDI)
# 194      Monaco                             ..
# 195       Nauru                             ..
# 196  San Marino                             ..
# 197     Somalia                             ..
# 198      Tuvalu                             ..

# %%
badHDIsymbols=[] # list for bad symbols

NumericColNames=hdi.iloc[:,1:].columns # save names of columns with numeric data

for columnName in NumericColNames:# visit every column name
    for cell in hdi[columnName]:# visit every cell for that column
        try:
            float(cell) # try this
        except: # if not possible:            
            if cell not in badHDIsymbols:# if cell is not in the list                
                badHDIsymbols.append(cell)# add it to the list

# you get:
badHDIsymbols
#shows all of the numeric columns
#that have non-numeric values or symbols
# Out:
# ['..']

# %%
import numpy as np
hdi.replace(to_replace=badHDIsymbols,value=np.nan,inplace=True)

# %%
hdi.tail()
# Out:
#         Country Human development index (HDI)
# 194      Monaco                            NaN
# 195       Nauru                            NaN
# 196  San Marino                            NaN
# 197     Somalia                            NaN
# 198      Tuvalu                            NaN

# %%
hdi.head()
# Out:
#                   Country Human development index (HDI)
# 0                  Norway                          0.954
# 1             Switzerland                          0.946
# 2                 Ireland                          0.942
# 3                 Germany                          0.939
# 4  Hong Kong, China (SAR)                          0.939

# %%
hdi
# Out:
#                     Country Human development index (HDI)
# 0                    Norway                          0.954
# 1               Switzerland                          0.946
# 2                   Ireland                          0.942
# 3                   Germany                          0.939
# 4    Hong Kong, China (SAR)                          0.939
# ..                      ...                            ...
# 194                  Monaco                            NaN
# 195                   Nauru                            NaN
# 196              San Marino                            NaN
# 197                 Somalia                            NaN
# 198                  Tuvalu                            NaN
#
# [199 rows x 2 columns]

# %%
hdi.dtypes
# Out:
# Country                           object
# Human development index (HDI)     object
# dtype: object

# %%
hdi[NumericColNames]=hdi.loc[:,NumericColNames].apply(pd.to_numeric)

# %%
hdi.dtypes
# Out:
# Country                            object
# Human development index (HDI)     float64
# dtype: object

# %%
hdi.median()
# Out:
# Human development index (HDI)     0.728
# dtype: float64

# %%
hdi.head(100)
# Out:
#                                Country  Human development index (HDI)
# 0                               Norway                           0.954
# 1                          Switzerland                           0.946
# 2                              Ireland                           0.942
# 3                              Germany                           0.939
# 4               Hong Kong, China (SAR)                           0.939
# ..                                 ...                             ...
# 95    Saint Vincent and the Grenadines                           0.728
# 96                             Jamaica                           0.726
# 97  Venezuela (Bolivarian Republic of)                           0.726
# 98                            Dominica                           0.724
# 99                                Fiji                           0.724
#
# [100 rows x 2 columns]

# %%
hdi['Human development index (HDI) '] = [1 if x >=.728 else 0 for x in hdi['Human development index (HDI) ']]

# %%
hdi
# Out:
#                     Country  Human development index (HDI)
# 0                    Norway                               1
# 1               Switzerland                               1
# 2                   Ireland                               1
# 3                   Germany                               1
# 4    Hong Kong, China (SAR)                               1
# ..                      ...                             ...
# 194                  Monaco                               0
# 195                   Nauru                               0
# 196              San Marino                               0
# 197                 Somalia                               0
# 198                  Tuvalu                               0
#
# [199 rows x 2 columns]

# %%
hdi.head(100)
# Out:
#                                Country  Human development index (HDI)
# 0                               Norway                               1
# 1                          Switzerland                               1
# 2                              Ireland                               1
# 3                              Germany                               1
# 4               Hong Kong, China (SAR)                               1
# ..                                 ...                             ...
# 95    Saint Vincent and the Grenadines                               1
# 96                             Jamaica                               0
# 97  Venezuela (Bolivarian Republic of)                               0
# 98                            Dominica                               0
# 99                                Fiji                               0
#
# [100 rows x 2 columns]

# %%
DF=pd.read_pickle("hdidemodexcia.pkl")

# %%
DF
# Out:
#                       Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                      Norway                  0.954                   82.3
# 1                 Switzerland                  0.946                   83.6
# 2                     Ireland                  0.942                   82.1
# 3                     Germany                  0.939                   81.2
# 4                   Hong Kong                  0.939                   84.7
# ..                        ...                    ...                    ...
# 159                      Mali                  0.427                   58.9
# 160                   Burundi                  0.423                   61.2
# 161                      Chad                  0.401                   54.0
# 162  Central African Republic                  0.381                   52.8
# 163                     Niger                  0.377                   62.0
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# ...

# %%
hdi.merge(DF)
# Out:
#                       Country  Human development index (HDI)   \
# 0                      Norway                               1
# 1                 Switzerland                               1
# 2                     Ireland                               1
# 3                     Germany                               1
# 4                   Australia                               1
# ..                        ...                             ...
# 142                      Mali                               0
# 143                   Burundi                               0
# 144                      Chad                               0
# 145  Central African Republic                               0
# 146                     Niger                               0
#
#      Humandevelopmentindex  Lifeexpectancyatbirth  Expectedyearsofschooling  \
# 0                    0.954                   82.3                      18.1
# ...

# %%
hdi.merge(DF,how='outer',indicator=True)
# Out:
#                                Country  Human development index (HDI)   \
# 0                               Norway                             1.0
# 1                          Switzerland                             1.0
# 2                              Ireland                             1.0
# 3                              Germany                             1.0
# 4               Hong Kong, China (SAR)                             1.0
# ..                                 ...                             ...
# 211                              Syria                             NaN
# 212                           Tanzania                             NaN
# 213                      Cote d'Ivoire                             NaN
# 214                        Gambia, The                             NaN
# 215  Congo, Democratic Republic of the                             NaN
#
#      Humandevelopmentindex  Lifeexpectancyatbirth  Expectedyearsofschooling  \
# ...

# %%
dirty=hdi.merge(DF,how='outer',indicator=True)

# %%
dirty.loc[dirty['_merge']=='right_only',"Country"]
# Out:
# 199                            Hong Kong
# 200                         Korea, South
# 201                               Russia
# 202                                 Iran
# 203                            Venezuela
# 204                              Moldova
# 205                              Bolivia
# 206                              Vietnam
# 207               Congo, Republic of the
# 208                             Eswatini
# 209                                 Laos
# 210                                Burma
# 211                                Syria
# 212                             Tanzania
# 213                        Cote d'Ivoire
# 214                          Gambia, The
# 215    Congo, Democratic Republic of the
# Name: Country, dtype: object

# %%
dirty.loc[dirty['_merge']=='left_only',"Country"]
# Out:
# 4                   Hong Kong, China (SAR)
# 17                           Liechtenstein
# 22                     Korea (Republic of)
# 35                                 Andorra
# 42                       Brunei Darussalam
# 48                      Russian Federation
# 54                                   Palau
# 55                                Barbados
# 59                                 Bahamas
# 61                              Seychelles
# 62                  HIGH HUMAN DEVELOPMENT
# 65              Iran (Islamic Republic of)
# 73                   Saint Kitts and Nevis
# 74                     Antigua and Barbuda
# 78                                 Grenada
# 90                             Saint Lucia
# 95        Saint Vincent and the Grenadines
# 97      Venezuela (Bolivarian Republic of)
# 98                                Dominica
# 103                                 Belize
# 104                               Maldives
# 105                                  Tonga
# ...

# %%
replacements1={'South Korea[n 1]': 'Korea (Republic of)', 
              'Cape Verde':'Cabo Verde',
              'Czech Republic':'Czechia',
              'Hong Kong':'Hong Kong, China (SAR)',
              'Moldova':'Moldova (Republic of)',
              'Bolivia':'Bolivia (Plurinational State of)',
              'Tanzania':'Tanzania (United Republic of)',
              'Palestine':'Palestine, State of',
              'Ivory Coast':"Côte d'Ivoire",
              'Republic of the Congo':'Congo',
              'Venezuela':'Venezuela (Bolivarian Republic of)',
              'Vietnam':'Viet Nam',
              'Eswatini':'Eswatini (Kingdom of)',              
              'Russia':'Russian Federation',
              'Iran':'Iran (Islamic Republic of)',
              'Laos':"Lao People's Democratic Republic",
              'Democratic Republic of the Congo':'Congo (Democratic Republic of the)',
              'Syria':'Syrian Arab Republic',
              'North Korea': "Korea (Democratic People's Rep. of)" #check ""
             }

# %%
DF.Country.replace(replacements1,inplace=True)

# %%
hdi.merge(DF)
# Out:
#                       Country  Human development index (HDI)   \
# 0                      Norway                               1
# 1                 Switzerland                               1
# 2                     Ireland                               1
# 3                     Germany                               1
# 4      Hong Kong, China (SAR)                               1
# ..                        ...                             ...
# 153                      Mali                               0
# 154                   Burundi                               0
# 155                      Chad                               0
# 156  Central African Republic                               0
# 157                     Niger                               0
#
#      Humandevelopmentindex  Lifeexpectancyatbirth  Expectedyearsofschooling  \
# 0                    0.954                   82.3                      18.1
# ...

# %%
hdidemodexcia2=hdi.merge(DF)

# %%
hdidemodexcia2
# Out:
#                       Country  Human development index (HDI)   \
# 0                      Norway                               1
# 1                 Switzerland                               1
# 2                     Ireland                               1
# 3                     Germany                               1
# 4      Hong Kong, China (SAR)                               1
# ..                        ...                             ...
# 153                      Mali                               0
# 154                   Burundi                               0
# 155                      Chad                               0
# 156  Central African Republic                               0
# 157                     Niger                               0
#
#      Humandevelopmentindex  Lifeexpectancyatbirth  Expectedyearsofschooling  \
# 0                    0.954                   82.3                      18.1
# ...

# %%
hdidemodexcia2.to_pickle("hdidemodexcia2.pkl")

# %%
pip install rpy2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(hdidemodexcia2,file="hdidemodexcia2.RDS")
# Out:
# <rpy2.rinterface.NULLType object at 0x12b3bf2d0> [RTYPES.NILSXP]
